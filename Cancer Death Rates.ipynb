# %% [markdown]
# ## Importing required libraries

# %%
#import pandas and numpy
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read Death Rates Dataset

# %%
death_rate_df = pd.read_excel("DeathRates.xlsx", index_col='State') #index_col eliminated the automatically
                                                                    #generated index and used state as index
death_rate_df.head()
# Out:
#             All cancer types combined  Brain and other nervous system  Breast  \
# State
# Alabama                         10520                             320     730
# Alaska                           1030                               0      70
# Arizona                         13200                             410     910
# Arkansas                         6460                             190     390
# California                      60970                            2070    4690
#
#             Cervix  Colorectum  Esophagus  Kidney and renal pelvis  Larynx  \
# State
# Alabama        110         910        250                      210      70
# Alaska           0         110          0                        0       0
# Arizona         80        1210        340                      350      70
# Arkansas        60         560        140                      190      50
# California     520        5470       1420                     1280     250
#
# ...

# %% [markdown]
# ### Importing Dataset
# ### Incident rate dataset

# %%
incident_rate_df = pd.read_excel("IncRate.xlsx",sheet_name=1,header=6, index_col="State") #sheet names start at index 0,,header removes unnecessary head info
incident_rate_df.head()
# Out:
#                   All cancer types combined / Both sexes combined  \
# State
# All U.S. combined                                             449
# Alabama                                                     450.8
# Alaska                                                      418.6
# Arizona                                                     385.7
# Arkansas                                                      479
#
#                   All cancer types combined / Female  \
# State
# All U.S. combined                                423
# Alabama                                        404.1
# Alaska                                         403.8
# Arizona                                        368.5
# Arkansas                                       430.9
#
#                   All cancer types combined / Male  \
# State
# All U.S. combined                            487.9
# Alabama                                      515.2
# Alaska                                       440.7
# ...

# %%
incident_rate_df.shape
# Out:
# (53, 78)

# %% [markdown]
# ### Importing New Cases Estimates dataset

# %%
new_case_estimate_df = pd.read_excel("NewCaseEstimates.xlsx",index_col="State")
new_case_estimate_df.head()
# Out:
#             All cancer types combined  Brain and other nervous system  \
# State
# Alabama                         30210                             370
# Alaska                           3250                              60
# Arizona                         39970                             550
# Arkansas                        18610                             220
# California                     189220                            2610
#
#             Breast- Female breast cancer only.  Cervix  Colorectum  Esophagus  \
# State
# Alabama                                   4280     240        2510        300
# Alaska                                     530       0         320         50
# Arizona                                   6110     290        3150        460
# Arkansas                                  2440     160        1530        180
# California                               31720    1640       15880       1800
#
# ...

# %% [markdown]
# ### ALL US INC RATE Dataset

# %%
all_us_df = pd.read_excel("IncRate.xlsx",sheet_name=0,header=6)
all_us_df
# Out:
#                          Cancer Type                 Both sexes combined  \
# 0          All cancer types combined                                 449
# 1     Brain and other nervous system                                 6.5
# 2                             Breast  126.9 - Female breast cancer only.
# 3                             Cervix                                 7.7
# 4           Colon (excluding rectum)                                25.4
# 5                         Colorectum                                36.5
# 6                          Esophagus                                 4.5
# 7                   Hodgkin lymphoma                                 2.6
# 8            Kidney and renal pelvis                                17.1
# 9                             Larynx                                 3.1
# 10                          Leukemia                                14.2
# 11  Liver and intrahepatic bile duct                                 8.6
# ...

# %%
## Replacing NaN values with 0
all_us_df.fillna(0,inplace=True)
all_us_df.head()
# Out:
#                       Cancer Type                 Both sexes combined  Female  \
# 0       All cancer types combined                                 449   423.0
# 1  Brain and other nervous system                                 6.5     5.5
# 2                          Breast  126.9 - Female breast cancer only.   126.9
# 3                          Cervix                                 7.7     7.7
# 4        Colon (excluding rectum)                                25.4    23.0
#
#     Male
# 0  487.9
# 1    7.6
# 2    0.0
# 3    0.0
# 4   28.1

# %%
# Query a specific column
all_us_df[['Both sexes combined']]
# Out:
#                    Both sexes combined
# 0                                  449
# 1                                  6.5
# 2   126.9 - Female breast cancer only.
# 3                                  7.7
# 4                                 25.4
# 5                                 36.5
# 6                                  4.5
# 7                                  2.6
# 8                                 17.1
# 9                                  3.1
# 10                                14.2
# 11                                 8.6
# 12                                57.3
# 13                                22.7
# 14                                   7
# 15                                19.2
# 16                                11.9
# 17                                10.7
# 18                                13.1
# 19                               106.4
# 20                                11.1
# 21                                 6.5
# 22                                 5.7
# ...

# %%
# CONVERTING COLUMN VALUES TO NUMERIC
all_us_df[["Both sexes combined"]].apply(pd.to_numeric,errors='coerce',axis=1)
all_us_df.head()
# Out:
#                       Cancer Type                 Both sexes combined  Female  \
# 0       All cancer types combined                                 449   423.0
# 1  Brain and other nervous system                                 6.5     5.5
# 2                          Breast  126.9 - Female breast cancer only.   126.9
# 3                          Cervix                                 7.7     7.7
# 4        Colon (excluding rectum)                                25.4    23.0
#
#     Male
# 0  487.9
# 1    7.6
# 2    0.0
# 3    0.0
# 4   28.1

# %%
all_us_df.values
# Out:
# array([['All cancer types combined', '449', 423.0, 487.9],
#        ['Brain and other nervous system', '6.5', 5.5, 7.6],
#        ['Breast', '126.9 - Female breast cancer only.', 126.9, 0.0],
#        ['Cervix', '7.7', 7.7, 0.0],
#        ['Colon (excluding rectum)', '25.4', 23.0, 28.1],
#        ['Colorectum', '36.5', 31.6, 42.1],
#        ['Esophagus', '4.5', 1.8, 7.8],
#        ['Hodgkin lymphoma', '2.6', 2.3, 3.0],
#        ['Kidney and renal pelvis', '17.1', 11.8, 23.2],
#        ['Larynx', '3.1', 1.2, 5.4],
#        ['Leukemia', '14.2', 11.0, 18.1],
#        ['Liver and intrahepatic bile duct', '8.6', 4.7, 13.1],
#        ['Lung and bronchus', '57.3', 50.8, 65.8],
#        ['Melanoma of the skin', '22.7', 18.0, 28.9],
#        ['Myeloma', '7', 5.7, 8.6],
#        ['Non-Hodgkin lymphoma', '19.2', 15.9, 23.1],
#        ['Oral cavity and pharynx', '11.9', 6.5, 18.1],
#        ['Ovary', '10.7', 10.7, 0.0],
#        ['Pancreas', '13.1', 11.5, 14.9],
# ...

# %%
all_us_df.replace(to_replace='126.9 - Female breast cancer only',value='nan', inplace=True)
all_us_df
# Out:
#                          Cancer Type Both sexes combined  Female   Male
# 0          All cancer types combined                 449   423.0  487.9
# 1     Brain and other nervous system                 6.5     5.5    7.6
# 2                             Breast                 nan   126.9    0.0
# 3                             Cervix                 7.7     7.7    0.0
# 4           Colon (excluding rectum)                25.4    23.0   28.1
# 5                         Colorectum                36.5    31.6   42.1
# 6                          Esophagus                 4.5     1.8    7.8
# 7                   Hodgkin lymphoma                 2.6     2.3    3.0
# 8            Kidney and renal pelvis                17.1    11.8   23.2
# 9                             Larynx                 3.1     1.2    5.4
# 10                          Leukemia                14.2    11.0   18.1
# 11  Liver and intrahepatic bile duct                 8.6     4.7   13.1
# ...

# %%
#DISPLAY ALL DATA TYPES
all_us_df.dtypes
# Out:
# Cancer Type             object
# Both sexes combined     object
# Female                 float64
# Male                   float64
# dtype: object

# %% [markdown]
# ## Data Cleaning
#
#
# ### Checking for null values

# %%
# checking incident rate
incident_rate_df.isnull().sum()
# Out:
# All cancer types combined / Both sexes combined          0
# All cancer types combined / Female                       0
# All cancer types combined / Male                         0
# Brain and other nervous system / Both sexes combined     0
# Brain and other nervous system / Female                  0
#                                                         ..
# Urinary bladder / Female                                 0
# Urinary bladder / Male                                   0
# Uterine corpus / Both sexes combined                     0
# Uterine corpus / Female                                  0
# Uterine corpus / Male                                   53
# Length: 78, dtype: int64
